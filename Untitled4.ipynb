# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
f=open("myfile.txt")
r=f.read()
# type(r)

cloud=WordCloud(background_color="white").generate(r)
plt.imshow(cloud)
plt.axis("off")
plt.show()
